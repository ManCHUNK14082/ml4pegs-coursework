# %% [markdown]
# <div style="background: linear-gradient(135deg, #1a3a5c 0%, #2d6a9f 100%); padding: 40px 32px 32px 32px; border-radius: 12px; margin-bottom: 8px;">
#   <h1 style="color: #ffffff; font-size: 2.2em; margin: 0 0 6px 0; font-family: 'Segoe UI', sans-serif; font-weight: 700; letter-spacing: 0.5px;">
#     🛢️ Machine Learning for Petroleum Engineers & Geoscientists (ML4PEGs)
#   </h1>
#   <h2 style="color: #a8d4f5; font-size: 1.3em; margin: 0 0 18px 0; font-family: 'Segoe UI', sans-serif; font-weight: 400;">
#     From Fundamentals to Advanced AI Applications in Energy and Subsurface Systems
#   </h2>
#   <hr style="border: 1px solid rgba(255,255,255,0.25); margin: 16px 0;">
#   <table style="color: #cce4ff; font-family: 'Segoe UI', sans-serif; font-size: 0.95em;">
#     <tr>
#       <td style="padding: 3px 24px 3px 0;"><strong>📅 Week:</strong></td><td>1 of 16 — Course Overview</td>
#       <td style="padding: 3px 24px 3px 32px;"><strong>⏱️ Duration:</strong></td><td>4 Months · 32 Contact Hours</td>
#     </tr>
#     <tr>
#       <td style="padding: 3px 24px 3px 0;"><strong>🎯 Phase:</strong></td><td>Month 1 — Foundations</td>
#       <td style="padding: 3px 24px 3px 32px;"><strong>👤 Audience:</strong></td><td>Engineers · Geoscientists · Researchers</td>
#     </tr>
#     <tr>
#       <td style="padding: 3px 24px 3px 0;"><strong>🧑‍🏫 Instructor:</strong></td><td>Dr. Daniel Wamriew</td>
#       <td style="padding: 3px 24px 3px 32px;"><strong>✉️ Contact:</strong></td><td>wamriewdan@gmail.com</td>
#     </tr>
#   </table>
# </div>

# %% [markdown]
# <div style="background: #e8f5e9; border-left: 5px solid #2ca87f; padding: 14px 20px; border-radius: 0 8px 8px 0; margin: 12px 0;">
#
# ### 💡 How to Use This Notebook
#
# You are inside a **Jupyter Notebook** — a document that combines explanatory text (like this cell) and runnable code.
#
# **To run a code cell:**
# - Click on it to select it, then press **Shift + Enter** — runs the cell and moves to the next one.
# - Or press **Ctrl + Enter** to run and stay on the same cell.
#
# **What to expect:**
# - Code cells have `[ ]` brackets on the left. After running, they show `[1]`, `[2]`, etc.
# - Output (numbers, tables, charts) appears directly below the code that produced it.
# - You cannot break anything by running a cell — if something goes wrong, just run it again.
#
# **First step:** Work through this notebook from top to bottom, pressing **Shift + Enter** on each cell as you go.
# </div>

# %% [markdown]
# ---
# ## 📋 Table of Contents
# 1. [Course Vision & Philosophy](#1-course-vision--philosophy)
# 2. [What Is Machine Learning?](#2-what-is-machine-learning)
# 3. [Why ML Matters in Energy](#3-why-ml-matters-in-energy)
# 4. [Course Structure & Roadmap](#4-course-structure--roadmap)
# 5. [Learning Outcomes](#5-learning-outcomes)
# 6. [Target Audience & Prerequisites](#6-target-audience--prerequisites)
# 7. [Software Stack](#7-software-stack)
# 8. [Assessment & Deliverables](#8-assessment--deliverables)
# 9. [Datasets We Will Use](#9-datasets-we-will-use)
# 10. [This Week's Practical](#10-this-weeks-practical)
#     - [10b. Useful Tools — Quick Reference](#10b-useful-tools--quick-reference)
# 11. [Week 1 Assignment](#11-week-1-assignment)

# %% [markdown]
# ---
# ## 1. Course Vision & Philosophy
#
# <div style="background: #f0f7ff; border-left: 5px solid #2d6a9f; padding: 16px 20px; border-radius: 0 8px 8px 0; margin: 12px 0;">
#   <em style="font-size: 1.05em; color: #1a3a5c;">
#   "This course is designed specifically for professionals and students in petroleum engineering, geophysics, geology, reservoir engineering, production engineering, and energy systems who want to apply modern machine learning to real subsurface and energy problems."
#   </em>
# </div>
#
# ### Core Philosophy
#
# The course follows **five key principles**:
#
# | # | Principle | What It Means |
# |---|-----------|---------------|
# | 1 | **Intuition first, not mathematics** | Understand *why* before *how* |
# | 2 | **Build practical coding ability early** | Write real code from Week 1 |
# | 3 | **Gradually introduce theory** | Math arrives when you need it |
# | 4 | **Real petroleum/geoscience examples throughout** | No abstract toy problems |
# | 5 | **End with advanced AI workflows** | Industry-relevant, research-ready |
#
# ### Who Is This Designed For?
#
# Learners with:
# - ✅ Minimal AI background
# - ✅ Moderate engineering mathematics
# - ✅ Little-to-no prior programming experience

# %% [markdown]
# ---
# ## 2. What Is Machine Learning?
#
# ### The AI Landscape

# %%
# This diagram was pre-generated for you — no need to understand this code yet.
from IPython.display import Image
Image('../assets/ai_landscape.png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# FileNotFoundError: No such file or directory: '../assets/ai_landscape.png'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# FileNotFoundError: No such file or directory: '../assets/ai_landscape.png'

# %% [markdown]
# > **What the diagram shows:** AI is the broadest category — it includes any technique that mimics human-like reasoning. Machine Learning (ML) is a subset of AI that *learns patterns from data* rather than following hand-coded rules. Deep Learning is a subset of ML that uses layered networks loosely inspired by the brain. In this course we cover ML and Deep Learning.

# %% [markdown]
# ### The Three Key Learning Paradigms
#
# | Paradigm | How It Learns | Petroleum Example |
# |----------|--------------|-------------------|
# | **Supervised Learning** | Learns from labelled input-output pairs | Predicting permeability from well-log data |
# | **Unsupervised Learning** | Finds hidden structure in unlabelled data | Automatic reservoir zonation by clustering |
# | **Reinforcement Learning** | Learns by trial and reward | Drilling parameter optimisation |
#
# ### Classification vs. Regression
#
# ```
# Is the output...
#     ├── A category?   →  CLASSIFICATION   (e.g., sandstone / shale / carbonate)
#     └── A number?     →  REGRESSION       (e.g., porosity = 18.4%)
# ```

# %% [markdown]
# ---
# ## 3. Why ML Matters in Energy
#
# The energy industry generates **vast, complex datasets** from:
# - 🕳️ Thousands of wells with multi-track logs
# - 🌊 3-D & 4-D seismic surveys (terabytes of data)
# - ⚙️ Real-time production sensors (SCADA, DAS, IoT)
# - 📡 Microseismic monitoring arrays
# - 🖥️ Reservoir simulation outputs
#
# Traditional methods struggle to extract full value. ML changes that.

# %%
# This chart was pre-generated for you — no need to understand this code yet.
from IPython.display import Image
Image('../assets/ml_impact.png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# FileNotFoundError: No such file or directory: '../assets/ml_impact.png'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# FileNotFoundError: No such file or directory: '../assets/ml_impact.png'

# %% [markdown]
# > **What to notice:** Seismic Interpretation and Well-Log Analysis score highest — these are the two areas where ML is most actively deployed in our industry today, and both are covered in depth in this course. Even lower-scoring areas like Microseismic Monitoring are already seeing real ML applications.

# %% [markdown]
# ---
# ## 4. Course Structure & Roadmap
#
# The course is organised into **four progressive phases**:

# %%
# This roadmap was pre-generated for you — no need to understand this code yet.
from IPython.display import Image
Image('../assets/course_roadmap.png')

# %% [markdown]
# ### Weekly Format
#
# Each week follows a consistent structure:
#
# | Time Block | Content |
# |------------|---------|
# | **30–45 min** | Lecture — concepts, theory, examples |
# | **60–75 min** | Hands-on practical in Jupyter |
# | **Take-home** | Mini-assignment (graded) |

# %% [markdown]
# ---
# ## 5. Learning Outcomes
#
# By the end of this 16-week course you will be able to:
#
# ### 🔬 Conceptual Understanding
# - Understand core machine learning concepts and paradigms
# - Understand deep learning fundamentals (architecture, training, tuning)
# - Understand uncertainty quantification and model limitations
# - Read and critique modern AI papers in geoscience
#
# ### 💻 Technical Skills
# - Build ML workflows in Python from scratch
# - Implement neural networks using PyTorch
# - Apply classical ML (scikit-learn) for real datasets
#
# ### 🛢️ Domain Applications
#
# | Application Area | Skills Gained |
# |------------------|--------------|
# | Petrophysics | Log-based property prediction |
# | Well Logs | Multi-track classification & regression |
# | Seismic | 2-D/3-D interpretation with CNNs |
# | Production | Time-series forecasting with LSTMs |
# | Drilling | Optimisation & anomaly detection |
# | Reservoir | Property mapping & characterisation |
# | Microseismic | Event detection & localisation |
#
# ### 🚀 Professional Outcomes
# - Design and execute your own ML project
# - Build a GitHub portfolio (5–10 completed notebooks)
# - Ability to prototype ML solutions independently

# %% [markdown]
# ---
# ## 6. Target Audience & Prerequisites
#
# ### Who Should Take This Course?
#
# | Role | Relevance |
# |------|-----------|
# | Petroleum Engineers | Production, reservoir, drilling applications |
# | Geophysicists | Seismic interpretation, signal processing |
# | Geologists | Facies classification, log analysis |
# | Reservoir Engineers | Simulation, history matching |
# | Drilling Engineers | ROP optimisation, bit wear |
# | Graduate Students | Research foundation in ML |
# | Energy Researchers | Scientific ML, PINNs |
# | Data Scientists | Subsurface domain onboarding |
#
# ### Prerequisites
#
# **Required (Minimal)**
# - High-school mathematics
# - Basic engineering background
#
# **Helpful but not required**
# - Python exposure
# - Basic statistics
# - Signal processing concepts
#
# > 💡 **You do not need prior programming experience. We start from zero.**

# %% [markdown]
# ---
# ## 7. Software Stack
#
# ### Core Tools
#
# ```
# Python          →  The language of modern data science & ML
# Jupyter Notebook →  Interactive coding environment (you are in one now!)
# VS Code         →  Code editor for larger projects
# Git / GitHub    →  Version control and portfolio building
# ```
#
# ### Python Libraries — Progressive Introduction
#
# ```
# Month 1 (Foundations)
#   ├── NumPy       — Numerical arrays & math
#   ├── Pandas      — Data tables & manipulation
#   └── Matplotlib  — Plotting & visualisation
#
# Month 2 (Classical ML)
#   └── Scikit-learn — Regression, classification, clustering
#
# Month 3 (Deep Learning)
#   └── PyTorch     — Neural networks & deep learning
#
# Throughout (Geoscience-specific)
#   ├── LASIO       — Read LAS well-log files
#   ├── segyio      — Read SEG-Y seismic files
#   ├── ObsPy       — Seismological data processing
#   └── PyVista     — 3-D visualisation
# ```

# %% [markdown]
# ---
# ## 🐍 Your First Lines of Python
#
# Before we check that your libraries are installed, let's run three short code cells — one new idea each. **Press Shift + Enter on each one.**

# %%
# A variable stores a value — think of it as a labelled box
course_name = "Machine Learning for Petroleum Engineers"
print(course_name)
# Out:
# Machine Learning for Petroleum Engineers

# %%
# A list holds multiple items in order
weeks = [1, 2, 3, 4]
print("First 4 weeks:", weeks)
print("Number of items in the list:", len(weeks))  # len() counts items in a list
# Out:
# First 4 weeks: [1, 2, 3, 4]
# Number of items in the list: 4

# %%
# Python can do arithmetic — try changing these numbers and pressing Shift+Enter to re-run
porosity = 0.22         # 22% porosity (fraction of rock that is pore space)
depth_m  = 2345.5       # measured depth in metres

print(f"Porosity: {porosity * 100:.1f}%")
print(f"Depth:    {depth_m:.1f} m")
print()
print("Try editing the numbers above and re-running the cell — the output will update.")
# Out:
# Porosity: 22.0%
# Depth:    2345.5 m
#
# Try editing the numbers above and re-running the cell — the output will update.

# %%
import numpy
import pandas
import matplotlib

print("numpy version:     ", numpy.__version__)
print("pandas version:    ", pandas.__version__)
print("matplotlib version:", matplotlib.__version__)
print()
print("All core libraries are ready!")
print("scikit-learn (ML) and PyTorch (deep learning) will be installed in later weeks.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 import numpy
#       2 import pandas
#       3 import matplotlib
#       4
#
# ModuleNotFoundError: No module named 'numpy'

# %% [markdown]
# ---
# ## 8. Assessment & Deliverables
#
# ### Grading Structure
#
# | Component | Weight | Details |
# |-----------|--------|---------|
# | Weekly Assignments | **40%** | 15 mini-projects, one per teaching week |
# | Practical Notebooks | **20%** | In-class Jupyter notebooks (completion + quality) |
# | Mini Quizzes | **10%** | Short concept checks, end of each month |
# | Final Project | **30%** | Full ML workflow on a petroleum/geoscience dataset |
#
# ### Final Project Options
#
# **Beginner Track**
# - Production forecasting with regression
# - Well-log property estimation
#
# **Intermediate Track**
# - Facies classification from multi-track well logs
# - Seismic horizon interpretation
#
# **Advanced Track**
# - Microseismic event localisation
# - CNN-based fault detection and seismic segmentation
# - Physics-guided (PINN) reservoir pressure prediction
#
# ### What You Will Leave With
# - 📁 GitHub portfolio with 5–10 completed notebooks
# - 📊 A final ML project (notebook + presentation + report)
# - 📖 Ability to read and critique AI papers in geoscience
# - 🛠️ Independent prototyping skills

# %% [markdown]
# ---
# ## 9. Datasets We Will Use
#
# ### Beginner / Warm-Up
# | Dataset | Use |
# |---------|-----|
# | Titanic (classic) | Classification intuition |
# | Simple CSV production data | First regression exercises |
#
# ### Petroleum & Geoscience
# | Dataset | Source | Application |
# |---------|--------|-------------|
# | **Volve Field Dataset** | Equinor (open) | Well logs, production, reservoir |
# | **FORCE Well Log Competition** | NPD / Equinor | Facies prediction challenge |
# | **SEG Open Data** | SEG | Seismic interpretation |
# | **Stanford Seismic Datasets** | Stanford | Seismic processing & ML |
# | **Microseismic Synthetic** | Generated | Event detection, localisation |
#
# > 🔗 All datasets are freely available and links will be provided in the relevant week's notebook.

# %% [markdown]
# ---
# ## 10. This Week's Practical
#
# ### Goal
# Get your environment running and load your first real dataset.
#
# **Steps:**
# 1. Verify Python & libraries (done above ✅)
# 2. Load a sample well-log CSV dataset
# 3. Inspect the data
# 4. Create your first simple plot

# %% [markdown]
# The next cell creates a **synthetic** (computer-simulated) well-log dataset — a table with 1,000 rows, one for each half-metre of depth in an imaginary well. Each row has four columns:
#
# | Column | Full Name | What It Measures |
# |--------|-----------|-----------------|
# | `DEPTH` | Measured Depth | How far down the borehole (metres) |
# | `GR` | Gamma Ray | Natural radioactivity — high GR = shale, low GR = sand |
# | `RHOB` | Bulk Density | Mass per unit volume of rock (g/cm³) |
# | `POROSITY` | Porosity | Fraction of the rock that is empty pore space (0 = solid rock, 0.38 = very porous) |
#
# > 📌 **DataFrame:** In Python, a `DataFrame` (from the `pandas` library) is like a spreadsheet — rows are measurements, columns are variables. You will use DataFrames in every notebook in this course.
#
# **Run the cell below.** You do not need to understand every line of the code — focus on reading the output table and statistics that appear.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# ─── Synthetic well-log dataset ───────────────────────────────────────────────
# (In Week 3 we will load a real LAS file using LASIO)
np.random.seed(42)
depth = np.arange(2000, 2500, 0.5)   # measured depth in metres
n = len(depth)

# Simulate three petrophysical logs
GR      = 40 + 60 * np.abs(np.sin(depth / 30)) + np.random.normal(0, 5, n)   # Gamma Ray (API)
RHOB    = 2.1 + 0.4 * (1 - np.abs(np.sin(depth / 30))) + np.random.normal(0, 0.03, n)  # Density (g/cc)
POROSITY = np.clip(0.30 - 0.25 * (RHOB - 2.1) / 0.4 + np.random.normal(0, 0.02, n), 0.05, 0.38)

df = pd.DataFrame({
    'DEPTH':    depth,
    'GR':       GR.round(2),
    'RHOB':     RHOB.round(3),
    'POROSITY': POROSITY.round(3)
})

print("=== Well Log Dataset ===")
print(f"Shape: {df.shape[0]} rows × {df.shape[1]} columns")
print(f"Depth range: {df.DEPTH.min()} – {df.DEPTH.max()} m")
print()
print(df.head(8).to_string(index=False))
print()
print("=== Basic Statistics ===")
print(df.describe().round(3).to_string())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 import numpy as np
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
#       4
#
# ModuleNotFoundError: No module named 'numpy'

# %%
# ─── First petroleum plot: a 3-track well log display ─────────────────────────
fig, axes = plt.subplots(1, 3, figsize=(11, 9), sharey=True)
fig.patch.set_facecolor('#f9fbff')

track_cfg = [
    ('GR',       'Gamma Ray (API)',      '#2d6a9f', (0, 150)),
    ('RHOB',     'Bulk Density (g/cc)',  '#e07b39', (1.9, 2.8)),
    ('POROSITY', 'Porosity (fraction)',  '#2ca87f', (0, 0.4)),
]

for ax, (col, label, color, xlim) in zip(axes, track_cfg):
    ax.plot(df[col], df['DEPTH'], color=color, linewidth=0.8, alpha=0.9)
    ax.set_xlabel(label, fontsize=10, fontweight='bold', color=color)
    ax.set_xlim(xlim)
    ax.set_facecolor('#f9fbff')
    ax.invert_yaxis()
    ax.grid(True, linestyle='--', alpha=0.35)
    ax.tick_params(labelsize=8)

axes[0].set_ylabel('Measured Depth (m)', fontsize=11, color='#1a3a5c')
fig.suptitle('Synthetic Well Log Display\
(Simulated — Real data from Week 3 onward)',
             fontsize=13, fontweight='bold', color='#1a3a5c', y=1.01)

plt.tight_layout()
plt.savefig('../assets/well_log_display.png', dpi=120, bbox_inches='tight', facecolor='#f9fbff')
plt.show()
print("Your first petroleum data visualisation — well done!")
# Out:
# Your first petroleum data visualisation — well done!

# %% [markdown]
# > **What to notice:** Depth increases downward — the same way you'd see it in a real borehole report. The Gamma Ray (GR) track oscillates: high values indicate clay-rich shale, low values indicate cleaner sandstone. Notice that where RHOB (density) is high, POROSITY tends to be low — denser rock has less pore space. **This inverse relationship is exactly the kind of pattern ML will learn to detect automatically.**

# %% [markdown]
# ---
# ## 10b. Useful Tools — Quick Reference
#
# The assignment asks you to use three Python patterns. Here they are fully worked out — **run each cell to see the output**, then copy the same structure into your assignment.
#
# ### A: Computing Statistics

# %%
# How to compute basic statistics for a single column
# Use df['COLUMN_NAME'] to select one column, then call a method on it.
print("─── Gamma Ray (GR) Statistics ───")
print(f"  Mean:  {df['GR'].mean():.2f}")    # average value
print(f"  Std:   {df['GR'].std():.2f}")     # spread — how much values vary
print(f"  Min:   {df['GR'].min():.2f}")
print(f"  Max:   {df['GR'].max():.2f}")
print(f"  Range: {df['GR'].max() - df['GR'].min():.2f}")   # max minus min
# Out:
# ─── Gamma Ray (GR) Statistics ───
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 4
#       1 # How to compute basic statistics for a single column
#       2 # Use df['COLUMN_NAME'] to select one column, then call a method on it.
#       3 print("─── Gamma Ray (GR) Statistics ───")
# ----> 4 print(f"  Mean:  {df['GR'].mean():.2f}")    # average value
#       5 print(f"  Std:   {df['GR'].std():.2f}")     # spread — how much values vary
#       6 print(f"  Min:   {df['GR'].min():.2f}")
#       7 print(f"  Max:   {df['GR'].max():.2f}")
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### B: Measuring Correlation
#
# **Correlation** tells us how strongly two measurements are linked. The result is always between −1 and +1.

# %%
# Compute the correlation between two columns.
# Correlation measures how strongly two measurements move together:
#   +1.0 = perfect positive relationship
#   -1.0 = perfect negative relationship
#    0.0 = no relationship
corr_value = df['RHOB'].corr(df['POROSITY'])
print(f"Correlation between RHOB and POROSITY: {corr_value:.3f}")
if corr_value < -0.5:
    print("→ Strong negative correlation: as density increases, porosity decreases.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 6
#       2 # Correlation measures how strongly two measurements move together:
#       3 #   +1.0 = perfect positive relationship
#       4 #   -1.0 = perfect negative relationship
#       5 #    0.0 = no relationship
# ----> 6 corr_value = df['RHOB'].corr(df['POROSITY'])
#       7 print(f"Correlation between RHOB and POROSITY: {corr_value:.3f}")
#       8 if corr_value < -0.5:
#       9     print("→ Strong negative correlation: as density increases, porosity decreases.")
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### C: Creating a Scatter Plot (Crossplot)
#
# A **scatter plot** (also called a crossplot in geoscience) shows the relationship between two measurements. Each dot is one depth point. Run the cell below — you will use this same pattern in the assignment.

# %%
import matplotlib.pyplot as plt

# A scatter plot shows the relationship between two measurements.
# Each dot represents one depth point in the well.
plt.figure(figsize=(6, 4))
plt.scatter(df['RHOB'], df['POROSITY'], color='steelblue', alpha=0.3, s=8)

plt.xlabel('Bulk Density RHOB (g/cc)')
plt.ylabel('Porosity (fraction)')
plt.title('RHOB vs Porosity — Crossplot')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
print("Notice the trend: higher density → lower porosity.")

# %% [markdown]
# ---
# ## 11. Week 1 Assignment
#
# <div style="background:#fff8e1; border-left:5px solid #f39c12; padding:16px 20px; border-radius:0 8px 8px 0; margin:12px 0;">
#
# ### 📝 Task: Explore a Well-Log Dataset
#
# **Objective:** Get comfortable loading, inspecting, and plotting tabular data in Python.
#
# **Instructions:**
#
# 1. **Run all cells** in this notebook top to bottom (use Kernel → Restart & Run All, or press Shift+Enter on each cell in order).
# 2. **Compute statistics** for all three logs (GR, RHOB, POROSITY) — use the exact pattern from **Section 10b-A**.
# 3. **Compute the correlation** between RHOB and POROSITY — use the pattern from **Section 10b-B**.
# 4. **Create a scatter plot** of RHOB vs POROSITY — use the pattern from **Section 10b-C**.
# 5. **Add a markdown cell** below your code and write 3–5 sentences describing what you observe. Does the correlation number match what the scatter plot looks like?
#
# **Bonus (optional):** Colour the scatter-plot dots by GR value — inside `plt.scatter()` add `c=df['GR'], cmap='viridis'`, then add `plt.colorbar(label='GR (API)')` on the next line.
#
# **Submission:** Submit your completed notebook (.ipynb) before the next session.
#
# </div>
#
# ### Your Code Goes Below

# %%
# ── Task 2: Statistics ──────────────────────────────────────────────────────
# Copy the pattern from Section 10b-A and repeat it for RHOB and POROSITY.
# Your code here:
# RHOB:
print("─── Bulk Density (RHOB) Statistics ───")
print(f"  Mean:  {df['RHOB'].mean():.2f}")    # average value
print(f"  Std:   {df['RHOB'].std():.2f}")     # spread — how much values vary
print(f"  Min:   {df['RHOB'].min():.2f}")
print(f"  Max:   {df['RHOB'].max():.2f}")
print(f"  Range: {df['RHOB'].max() - df['RHOB'].min():.2f}") 
# POROSITY:
print("─── Porosity Statistics ───")
print(f"  Mean:  {df['POROSITY'].mean():.3f}")    # average value
print(f"  Std:   {df['POROSITY'].std():.3f}")     # spread — how much values vary
print(f"  Min:   {df['POROSITY'].min():.3f}")
print(f"  Max:   {df['POROSITY'].max():.3f}")
print(f"  Range: {df['POROSITY'].max() - df['POROSITY'].min():.3f}")

      
# ── Task 3: Correlation ─────────────────────────────────────────────────────
# Copy the pattern from Section 10b-B.
# Your code here:
corr_value = df['RHOB'].corr(df['POROSITY'])
print(f"Correlation between RHOB and POROSITY: {corr_value:.3f}")
if corr_value < -0.5:
    print("→ Strong negative correlation: as density increases, porosity decreases.")


# ── Task 4: Scatter Plot ────────────────────────────────────────────────────
# Copy the pattern from Section 10b-C.
# Your code here:
plt.figure(figsize=(6, 4))
plt.scatter(df['RHOB'], df['POROSITY'], color='steelblue', alpha=0.3, s=8)

plt.xlabel('Bulk Density RHOB (g/cc)')
plt.ylabel('Porosity (fraction)')
plt.title('RHOB vs Porosity — Crossplot')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
print("Notice the trend: higher density → lower porosity.")
# Out:
# ─── Bulk Density (RHOB) Statistics ───
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 6
#       2 # Copy the pattern from Section 10b-A and repeat it for RHOB and POROSITY.
#       3 # Your code here:
#       4 # RHOB:
#       5 print("─── Bulk Density (RHOB) Statistics ───")
# ----> 6 print(f"  Mean:  {df['RHOB'].mean():.2f}")    # average value
#       7 print(f"  Std:   {df['RHOB'].std():.2f}")     # spread — how much values vary
#       8 print(f"  Min:   {df['RHOB'].min():.2f}")
#       9 print(f"  Max:   {df['RHOB'].max():.2f}")
#
# NameError: name 'df' is not defined

# %% [markdown]
# ---
#
# <div style="background: linear-gradient(135deg, #1a3a5c 0%, #2d6a9f 100%); padding: 24px 28px; border-radius: 12px; text-align: center; margin-top: 20px;">
#   <h3 style="color: #ffffff; margin: 0 0 10px 0; font-family: 'Segoe UI', sans-serif;">
#     🚀 See You in Week 2 — Python for Data Science
#   </h3>
#   <p style="color: #a8d4f5; margin: 0; font-size: 0.95em;">
#     Next week: Variables · Lists · Arrays · NumPy · Production-rate analysis
#   </p>
# </div>
#
# ---
# *Machine Learning for Petroleum Engineers & Geoscientists — Week 1 Notebook*
# *Course material follows a layered progression: intuition → practice → theory → advanced applications.*
