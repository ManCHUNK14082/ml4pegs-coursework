# %% [markdown]
# <div style="background: linear-gradient(135deg, #1a3a5c 0%, #2d6a9f 100%); padding: 40px 32px 32px 32px; border-radius: 12px; margin-bottom: 8px;">
#   <h1 style="color: #ffffff; font-size: 2.0em; margin: 0 0 6px 0; font-family: 'Segoe UI', sans-serif; font-weight: 700;">
#     Month 1 Quiz -- Concept Check
#   </h1>
#   <h2 style="color: #a8d4f5; font-size: 1.2em; margin: 0 0 18px 0; font-family: 'Segoe UI', sans-serif; font-weight: 400;">
#     Python, NumPy, Pandas &amp; Introduction to Machine Learning (Lessons 1-8)
#   </h2>
#   <hr style="border: 1px solid rgba(255,255,255,0.25); margin: 16px 0;">
#   <table style="color: #cce4ff; font-family: 'Segoe UI', sans-serif; font-size: 0.95em;">
#     <tr>
#       <td style="padding: 3px 24px 3px 0;"><strong>Covers:</strong></td><td>Lessons 1-8 (Weeks 1-4)</td>
#       <td style="padding: 3px 24px 3px 32px;"><strong>Duration:</strong></td><td>25 Minutes</td>
#     </tr>
#     <tr>
#       <td style="padding: 3px 24px 3px 0;"><strong>Track:</strong></td><td>Petroleum Engineers &amp; Geoscientists</td>
#       <td style="padding: 3px 24px 3px 32px;"><strong>Total Points:</strong></td><td>18</td>
#     </tr>
#     <tr>
#       <td style="padding: 3px 24px 3px 0;"><strong>Instructor:</strong></td><td>Dr. Daniel Wamriew</td>
#       <td style="padding: 3px 24px 3px 32px;"><strong>Contact:</strong></td><td>wamriewdan@gmail.com</td>
#     </tr>
#   </table>
# </div>

# %% [markdown]
# <div style="background: #e8f5e9; border-left: 5px solid #2ca87f; padding: 14px 20px; border-radius: 0 8px 8px 0; margin: 12px 0;">
#
# ### How to Use This Quiz
#
# This is a **closed-book concept check** -- no need to run code or look anything up. It counts toward the
# **Mini Quizzes (10%)** component of your grade.
#
# - Every question is a **markdown cell**. Double-click a cell to edit it, type your answer directly below
#   the question, then press **Shift + Enter** to render it back to readable text.
# - **Multiple choice:** write the letter of your answer (e.g. `Answer: b`).
# - **Short answer:** 1-3 sentences is enough -- we are checking understanding, not essay length.
# - **Code reading:** predict the output without running anything.
# - Work through the four parts in order. Raise your hand if a question is unclear.
# - Submit the completed notebook on Google Classroom before the end of class.
#
# </div>

# %% [markdown]
# ---
# ## Part A -- Python & NumPy (5 points)

# %% [markdown]
# **Q1 (1 pt).** What does `type(5 / 2)` return in Python?
#
# a) `int`
# b) `float`
# c) `str`
# d) an error
#
# **Answer:** a

# %% [markdown]
# **Q2 (1 pt).** Which data structure lets you store mixed types and change its contents after creation?
#
# a) tuple
# b) list
# c) string
# d) integer
#
# **Answer:** c

# %% [markdown]
# **Q3 (1 pt).** If `gr` is a NumPy array, what does `gr > 100` return?
#
# a) A single `True` or `False`
# b) A boolean array, one value per element of `gr`
# c) An error, because arrays cannot be compared
# d) The count of values above 100
#
# **Answer:** a

# %% [markdown]
# **Q4 (1 pt).** Why do we prefer NumPy arrays over plain Python lists for well log calculations?
#
# a) Arrays support vectorized math without writing an explicit loop
# b) Arrays cannot hold negative numbers
# c) Lists are faster for numeric math
# d) Arrays always use less memory than lists
#
# **Answer:** d

# %% [markdown]
# **Q5 (1 pt).** What does `np.where(gr < 75, "Sand", "Shale")` do?
#
# a) Deletes every row where GR is above 75
# b) Creates a new array labeling each value "Sand" or "Shale" based on the condition
# c) Sorts the array from lowest to highest GR
# d) Counts how many values are below 75
#
# **Answer:** b

# %% [markdown]
# ---
# ## Part B -- Pandas & Data Handling (5 points)

# %% [markdown]
# **Q6 (1 pt).** What does `df.groupby("Formation")["RHOB_gcc"].mean()` compute?
#
# a) The mean RHOB for the entire dataset
# b) The mean RHOB for each formation, separately
# c) The formation with the single highest RHOB value
# d) A count of rows in each formation
#
# **Answer:** b

# %% [markdown]
# **Q7 (1 pt).** Which method fills a missing well log value using the last known value *above* it in the same column?
#
# a) `bfill()`
# b) `dropna()`
# c) `ffill()`
# d) `fillna(0)`
#
# **Answer:** c

# %% [markdown]
# **Q8 (2 pts, short answer).** In our well log workflow we always `ffill()`/`bfill()` **within each `Well_ID`
# group** (`df.groupby("Well_ID")[log_cols].ffill()`) rather than filling straight down the whole DataFrame.
# Why does grouping by well matter here?
#
# **Answer:** Grouping by well matters because it gives a proper division of data.

# %% [markdown]
# **Q9 (1 pt).** A LAS file is best described as:
#
# a) A spreadsheet of daily production rates
# b) A standard text format for storing well log curve data, with depth and header metadata
# c) A seismic image file
# d) A saved machine learning model
#
# **Answer:** c

# %% [markdown]
# ---
# ## Part C -- Introduction to Machine Learning (7 points)

# %% [markdown]
# **Q10 (2 pts, short answer).** What is the difference between regression and classification? Give one
# example of each **from this course**.
#
# **Answer:** regression is drawing a curve based on data collected while classification is grouping of data based of the information it gives

# %% [markdown]
# **Q11 (1 pt).** Why do we split data into a training set and a test set?
#
# a) To make the model train faster
# b) To evaluate the model on data it has never seen, simulating real-world use
# c) scikit-learn requires at least two datasets to run
# d) To reduce the number of features
#
# **Answer:** b

# %% [markdown]
# **Q12 (2 pts, short answer).** A regression model has a high R², but its residual plot shows a clear curved
# pattern instead of random scatter around zero. What does this suggest about the model?
#
# **Answer:** it is linear

# %% [markdown]
# **Q13 (1 pt).** Which evaluation metric is expressed in the same units as the target variable, making it
# directly interpretable (e.g. "off by 0.02 porosity units")?
#
# a) R²
# b) RMSE
# c) Accuracy
# d) F1-score
#
# **Answer:** d

# %% [markdown]
# ---
# ## Part D -- Code Reading (2 points)
#
# Predict the output of each snippet without running it.

# %% [markdown]
# **Q14 (1 pt).**
#
# ```python
# prices = [10, 20, 30]
# total = 0
# for p in prices:
#     total += p
# print(total)
# ```
#
# **Answer:** 60

# %% [markdown]
# **Q15 (1 pt).**
#
# ```python
# import numpy as np
# arr = np.array([5, 12, 8, 20])
# print(arr[arr > 10])
# ```
#
# **Answer:** 12, 20

# %% [markdown]
# <div style="background: #1a3a5c; color: white; padding: 22px 26px; border-radius: 10px; margin-top: 18px;">
#   <h3 style="margin-top: 0; color: #ffffff;">End of Quiz</h3>
#   <p style="margin-bottom: 0; color: #d8ecff;">
#     Double-check every question has an answer, then save and submit this notebook on Google Classroom.
#     Well done getting through Month 1 -- Month 2 picks up with classification, ensembles, and unsupervised learning.
#   </p>
# </div>
